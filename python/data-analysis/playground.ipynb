# %%
# Enter your code here. Read input from STDIN. Print output to STDOUTimport numpy
from scipy import interpolate
import matplotlib.pyplot as plt

# read data
n = """60"""
text = """MonthNum_1 1226800
MonthNum_2 926891
MonthNum_3 782725
MonthNum_4 1023038
MonthNum_5 1126293
MonthNum_6 692565
MonthNum_7 1165880
MonthNum_8 1207156
MonthNum_9 1129954
MonthNum_10 745100
MonthNum_11 1059346
MonthNum_12 1168555
MonthNum_13 1317458
MonthNum_14 528045
MonthNum_15 1220238
MonthNum_16 874557
MonthNum_17 1033389
MonthNum_18 1034165
MonthNum_19 812094
MonthNum_20 1351419
MonthNum_21 801822
MonthNum_22 1044266
MonthNum_23 722871
MonthNum_24 742100
MonthNum_25 839471
MonthNum_26 1201199
MonthNum_27 796265
MonthNum_28 953887
MonthNum_29 1124602
MonthNum_30 1070181
MonthNum_31 1160366
MonthNum_32 1131150
MonthNum_33 1151813
MonthNum_34 1065316
MonthNum_35 914800
MonthNum_36 1093034
MonthNum_37 937898
MonthNum_38 991612
MonthNum_39 865649
MonthNum_40 990565
MonthNum_41 965414
MonthNum_42 949248
MonthNum_43 1168905
MonthNum_44 593112
MonthNum_45 1156922
MonthNum_46 870095
MonthNum_47 1023262
MonthNum_48 788327
MonthNum_49 543605
MonthNum_50 510786
MonthNum_51 734714
MonthNum_52 1133025
MonthNum_53 1461091
MonthNum_54 635481
MonthNum_55 1104107
MonthNum_56 844960
MonthNum_57 1271967
MonthNum_58 574319
MonthNum_59 1063900
MonthNum_60 724737"""
history = []
months=[]
# print(text.splitlines())
for index, line in enumerate(text.splitlines()):
    l_l = line.split(' ')
    if len(l_l) == 1:
        continue
    # print(l__l)
    months.append(float(l_l[1]))
    history.append(index)

future = []
for i in range(12):
    future.append(len(history) + i)
# print(future)
# print(months)

# build model
pred_model = interpolate.UnivariateSpline(history, months, s=1)
for x in future:
    print(pred_model(x))
    
# Plot history and future
plt.plot(range(len(history)), months, 'ro', label='History')
plt.plot(range(len(history)), pred_model(range(len(history))), 'b', label='Interpolated')
# plt.plot(future, pred_model(future), 'g--', label='Future Prediction')
plt.xlabel('Months')
plt.ylabel('Values')
plt.title('Interpolated and Predicted Values Over Time')
plt.legend()
plt.show()
# Out:
# -4002091.906105476
# -16675509.087438539
# -40854436.80593088
# -80097797.3349296
# -137964512.94778177
# -218013505.9178345
# -323803698.5184348
# -458894013.0229299
# -626843371.7046669
# -831210696.8369927
# -1075554910.6932542
# -1363434935.5467992

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
from scipy import interpolate

# read data
n = input()

x_known = []
y_known = []
x_missing = []
for i in range(int(n)):
    line = input()
    items = line.split('\t')
    if "Missing_" in items[1]:
        x_missing.append(i)
        continue
    x_known.append(i) 
    y_known.append(float(items[1]))

# build model
pred_model = interpolate.UnivariateSpline(x_known, y_known, s=1)
for x in x_missing:
    print(pred_model(x))



# def calcMissing(readings):
#     # Write your code here
#     datas = []
#     existings = []
#     missings = []
#     for index, reading in enumerate(readings):
#         date_time, data = reading.split("\t")
#         if "Missing_" in data:
#             missings.append(index)
#             continue
#         datas.append(float(data))
#         existings.append(index)
    
#     pred_model = interpolate.UnivariateSpline(existings, datas, s=2)
#     for i in missings:
#         print(pred_model(i))

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Historical web traffic data (replace this with your own data)
# For demonstration purposes, let's assume we have 100 days of data
historical_traffic = np.array([100, 120, 150, 130, 140, 160, 170, 180, 190, 200,
                               210, 220, 230, 240, 250, 260, 270, 280, 290, 300,
                               310, 320, 330, 340, 350, 360, 370, 380, 390, 400,
                               410, 420, 430, 440, 450, 460, 470, 480, 490, 500,
                               510, 520, 530, 540, 550, 560, 570, 580, 590, 600,
                               610, 620, 630, 640, 650, 660, 670, 680, 690, 700,
                               710, 720, 730, 740, 750, 760, 770, 780, 790, 800,
                               810, 820, 830, 840, 850, 860, 870, 880, 890, 900,
                               910, 920, 930, 940, 950, 960, 970, 980, 990, 1000])

# Reshape the data for linear regression (required by scikit-learn)
X = np.arange(len(historical_traffic)).reshape(-1, 1)
# print(X)
y = historical_traffic

# Fit linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict web traffic for the next 20 days
future_days = np.arange(len(historical_traffic), len(historical_traffic) + 20).reshape(-1, 1)
predicted_traffic = model.predict(future_days)

# Print predicted traffic for the next 20 days
print("Predicted traffic for the next 20 days:")
for day, traffic in enumerate(predicted_traffic, start=1):
    print(f"Day {day}: {traffic:.2f}")

# You can also plot the historical data and the predicted values if needed
# Out:
# Predicted traffic for the next 20 days:
# Day 1: 1010.20
# Day 2: 1020.21
# Day 3: 1030.21
# Day 4: 1040.22
# Day 5: 1050.23
# Day 6: 1060.23
# Day 7: 1070.24
# Day 8: 1080.25
# Day 9: 1090.25
# Day 10: 1100.26
# Day 11: 1110.27
# Day 12: 1120.27
# Day 13: 1130.28
# Day 14: 1140.29
# Day 15: 1150.30
# Day 16: 1160.30
# Day 17: 1170.31
# Day 18: 1180.32
# Day 19: 1190.32
# Day 20: 1200.33

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
import numpy as np
from scipy import interpolate
from sklearn.linear_model import Lasso
from scipy.fft import fft, ifft
from statsmodels.tsa.arima.model import ARIMA

# read data
n = "500"
text = """500
1339
1462
1702
1656
1439
1208
1613
1935
1964
2003
2023
1559
1274
1805
2051
2024
2049
1998
1441
1257
1559
1643
1464
1521
1576
1381
1372
1610
1926
2018
1930
1868
1551
1471
1954
2079
2061
2001
2031
1574
1165
1366
1384
1342
1543
1509
1598
1349
1625
1932
2079
1857
1443
1332
1149
1471
1595
1498
1433
1401
1178
972
1283
1468
1456
1466
1378
1208
1038
1344
1379
1418
1466
1414
1129
948
1285
1373
1379
599
614
850
672
747
732
834
996
900
792
688
781
696
834
1026
974
1001
997
1110
1212
1301
1322
1253
935
857
1082
1112
1291
1391
1384
1089
963
1174
1420
1349
1338
1335
1075
952
1376
1586
1571
1543
1525
1223
1066
1555
1704
1745
1749
1687
1288
1152
1492
1728
1742
1732
1510
1288
1280
1659
1852
1823
1723
1416
1187
1014
1324
1618
1736
1552
1598
1158
1083
1383
1595
1540
1551
1447
1128
1057
1371
1746
1653
1726
1759
1297
1165
1480
1693
1744
1661
1575
1199
1062
1395
1555
1441
1399
    # Fit ARIMA model
    model = ARIMA(y_his, order=(5,1,0)) # Example order, adjust as needed
    fit_model = model.fit()

    # Predict next 20 days
    predicted_traffic = fit_model.forecast(steps=days)
    for r in predicted_traffic:
        print(r)
    return predicted_traffic
        

# do the job
y_pred = predictFutureARIMA(x_his, y_his, 30)

# plot data
plt.plot(x_his, y_his)
plt.plot(X_future, y_pred)
plt.show()
# Out:
# 1861.6960690911144
# 1644.5336684274544
# 1588.6502834706666
# 1671.3126057712716
# 1739.0367591586541
# 1800.6585506503527
# 1851.8183486839869
# 1805.5148597944276
# 1714.4378070697105
# 1677.6334565568789
# 1691.666106309866
# 1724.2006231903085
# 1771.563226266782
# 1800.1047989382266
# 1781.1473630866535
# 1741.2649022319576
# 1716.1269868673257
# 1711.9991623346582
# 1727.5171380024976
# 1754.674752414511
# 1771.7922019065222
# 1766.7627972462035
# 1749.3280053023525
# 1733.3311389943492
# 1726.798643559238
# 1733.066111774222
# 1747.058992350289
# 1757.3995325821948
# 1757.7150677289942
# 1750.2964806003176

# %%
data = """100 10 20
CAL 0 121.83 122.26 123.94 122.11 120.58
UCB 0 52.34 50.89 47.62 51.16 52.4
RIT 0 100.21 99.33 102.87 110.63 110.72
UCLA 0 12.5 27.22 9.32 16.07 3.86
USC 0 249.58 244.24 242.56 245.13 245.35
UFL 0 20.21 19.77 21.34 20.21 21.17
UMAD 0 109.39 120.49 131.35 127.97 121.38
RICE 0 126.3 128 129.08 129.28 124.44
UMD 0 102.96 103.62 98.22 96.6 99.1
UCSC 0 213.77 193.51 178.53 180.08 208.29"""

m, k, d = map(int, data.splitlines()[0].split())
name = []
owned = []
prices = []
for line in data.splitlines()[1:]:
    items = line.split()
    name.append(items[0])
    owned.append(int(items[1]))
    prices.append(list(map(float, items[2:])))

def printTransactions(m, k, d, name, owned, prices):
    # Write your code here
    # print(m, k, d, name, owned, prices)
    
    # print the highest price, lowest price and average of each stock
    increase_ratio = []
    for i in range(k):
        # calculate the highest increment ratio
        # larger indicates the stock is increasing
        # lower indicates the stock is decreasing
        # print(name[i], max(prices[i]), min(prices[i]), sum(prices[i])/len(prices[i]))
        # print(prices[i][4], prices[i][4]/(sum(prices[i])/len(prices[i])))
        
        increase_ratio.append(prices[i][4]/(sum(prices[i])/len(prices[i])))
        
    # find the index of the stock with the highest increment ratio and the lowest increment ratio
    max_index = increase_ratio.index(max(increase_ratio))
    min_index = increase_ratio.index(min(increase_ratio))
    
    commands = []
    # if I owned the stock with the highest increment ratio, sell it
    if owned[max_index] > 0:
        # print(name[max_index], "SELL", owned[max_index])
        commands.append(name[max_index] + " SELL " + str(owned[max_index]))
    # if I don't own the stock with the lowest increment ratio, buy it
    if owned[min_index] == 0:
        # print(name[min_index], "BUY", m//prices[min_index][4])
        commands.append(name[min_index] + " BUY " + str(m//prices[min_index][4]))
    operations = []
    operations.append(len(commands))
    operations.extend(commands)
    for o in operations:
        print(o)
    
printTransactions(m, k, d, name, owned, prices)
# Out:
# 1
# UCLA BUY 25.0
